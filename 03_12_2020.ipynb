# %% [markdown]
# <a href="https://colab.research.google.com/github/SaidVargasB/cyp_2021/blob/main/03_12_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejemplo 1
for i in [1,2,3,5]:
  print(f"El elemento: {i}")
# Out:
# El elemento: 1
# El elemento: 2
# El elemento: 3
# El elemento: 5

# %%
#Ejemplo 2

coleccion={"Mario":20, "Mariana":19, "Yessica":14, "Luis":10}
for i in coleccion:
  print(f"El elemento: {i}")
# Out:
# El elemento: Mario
# El elemento: Mariana
# El elemento: Yessica
# El elemento: Luis

# %%
#Ejemplo 2.1

coleccion={"Mario":20, "Mariana":19, "Yessica":14, "Luis":10}
for i in coleccion:
  print(f"{coleccion [i]}")
# Out:
# 20
# 19
# 14
# 10

# %%
#Ejemplo 2.3
coleccion={"Mario":20, "Mariana":19, "Yessica":14, "Luis":10}
for i in coleccion:
  print(f"{i}-->{coleccion[i]}")
# Out:
# Mario-->20
# Mariana-->19
# Yessica-->14
# Luis-->10

# %%
#Ejemplo 3

email= False
for i in"arielunam.mx":
  if(i=="@"):
    email=True
if email==True:
    print("El email es correcto")
else:
  print("El email es incorrecto")
# Out:
# El email es incorrecto

# %%
#Ejemplo 3.1

email= False
miemail= input("Introduce tu correo electrónico: ")
for i in"ariel@unam.mx":
  if(i=="@"):
    email=True
if email==True:
    print("El email es correcto")
else:
  print("El email es incorrecto")
# Out:
# Introduce tu correo electrónico: saidvargas@unam.mx
# El email es correcto

# %%
#For-Range

for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(20):
  print("Valor de la variable", i)
# Out:
# Valor de la variable 0
# Valor de la variable 1
# Valor de la variable 2
# Valor de la variable 3
# Valor de la variable 4
# Valor de la variable 5
# Valor de la variable 6
# Valor de la variable 7
# Valor de la variable 8
# Valor de la variable 9
# Valor de la variable 10
# Valor de la variable 11
# Valor de la variable 12
# Valor de la variable 13
# Valor de la variable 14
# Valor de la variable 15
# Valor de la variable 16
# Valor de la variable 17
# Valor de la variable 18
# Valor de la variable 19

# %%
#While Ejemplos
#Ejemplo 1 Bucle
i=1
while i<=10: 
  print("Ejecución", i)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# Ejecución 1
# ...

# %%
#While Ejemplos
#Ejemplo 1 Bucle
i=1
while i<=10: 
  print("Ejecución",str (i))
  i=i+1 #Contador, es decir, incrementa en 1 la variable
# Out:
# Ejecución 1
# Ejecución 2
# Ejecución 3
# Ejecución 4
# Ejecución 5
# Ejecución 6
# Ejecución 7
# Ejecución 8
# Ejecución 9
# Ejecución 10

# %%
#Ejemplo 
edad= int(input("Introduce tu edad: "))
while edad < 0:
  print("Has intoducido una edad invalida. Intente nuevamente.")
  edad= int(input("Introduce tu edad: "))
  print("Gracias por participar. Puede pasar.")
  print("Edad del Aspirante: "+str (edad))
# Out:
# Introduce tu edad: -9
# Has intoducido una edad invalida. Intente nuevamente.
# Introduce tu edad: -5
# Gracias por participar. Puede pasar.
# Edad del Aspirante: -5
# Has intoducido una edad invalida. Intente nuevamente.
# Introduce tu edad: -3
# Gracias por participar. Puede pasar.
# Edad del Aspirante: -3
# Has intoducido una edad invalida. Intente nuevamente.
# Introduce tu edad: 18
# Gracias por participar. Puede pasar.
# Edad del Aspirante: 18

# %%
#Ejemplo
edad= int(input("Introduce tu edad: "))
while edad < 10 or edad<10=100:
  print("Has intoducido una edad invalida. Intente nuevamente.")
  edad= int(input("Introduce tu edad: "))
  print("Gracias por participar. Puede pasar.")
  print("Edad del Aspirante: "+str (edad))
# Out:
# Introduce tu edad: -5
# Has intoducido una edad invalida. Intente nuevamente.
# Introduce tu edad: 4
# Gracias por participar. Puede pasar.
# Edad del Aspirante: 4
# Has intoducido una edad invalida. Intente nuevamente.
# Introduce tu edad: 18
# Gracias por participar. Puede pasar.
# Edad del Aspirante: 18
# Has intoducido una edad invalida. Intente nuevamente.
# Introduce tu edad: 110
# Gracias por participar. Puede pasar.
# Edad del Aspirante: 110
